# %%
from bs4 import BeautifulSoup
import requests as reqs

# %%
page = reqs.get('https://cmsc320.github.io/')

# %%
page.text
# Out:
# '<DOCTYPE html>\n<html lang="en">\n    <head>\n        \n        <meta charset="utf-8" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n        <meta name="viewport" content="width=device-width, initial-scale=1" />\n        <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\n        <meta name="description" content="Introduction to Data Science" />\n        <meta name="author" content="John P. Dickerson" />\n        <link rel="icon" href="favicon.ico" />\n        \n        <title>Introduction to Data Science</title>\n        \n        <!-- Bootstrap core CSS -->\n        <link href="css/bootstrap.min.css" rel="stylesheet" />\n        \n        <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->\n        <link href="css/ie10-viewport-bug-workaround.css" rel="stylesheet" />\n        \n        <!-- Custom styles for this template -->\n        <link href="css/jumbotron-narrow.css" rel="stylesheet
# ...

# %%
soup = BeautifulSoup(page.text)

# %%
soup.prettify()
# Out:
# '<html>\n <body>\n  <doctype html="">\n   <meta charset="utf-8"/>\n   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n   <meta content="width=device-width, initial-scale=1" name="viewport"/>\n   <!-- The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags -->\n   <meta content="Introduction to Data Science" name="description"/>\n   <meta content="John P. Dickerson" name="author"/>\n   <link href="favicon.ico" rel="icon"/>\n   <title>\n    Introduction to Data Science\n   </title>\n   <!-- Bootstrap core CSS -->\n   <link href="css/bootstrap.min.css" rel="stylesheet"/>\n   <!-- IE10 viewport hack for Surface/desktop Windows 8 bug -->\n   <link href="css/ie10-viewport-bug-workaround.css" rel="stylesheet"/>\n   <!-- Custom styles for this template -->\n   <link href="css/jumbotron-narrow.css" rel="stylesheet"/>\n   <!-- Just for debugging purposes. Don\'t actually copy these 2 lines! -->\n   <!--[if lt IE 9]><script src="../../ass
# ...

# %%
tables = soup.findAll('table')

# %%
tables[0]
# Out:
# <table class="table table-striped">
# <caption>Office Hours (all times EDT)</caption>
# <thead>
# <tr>
# <th style="width: 30%">Human</th>
# <th style="width: 45%">Time</th>
# <th style="width: 25%">Location</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Anubhav</td>
# <td>TBD</td>
# <td>Online</td>
# </tr>
# <tr>
# <td>José Manuel Calderón Trilla</td>
# <td>By appointment; please email José (jmct@umd.edu) with <code>[CMSC320]</code> in the email subject line.</td>
# <td>Zoom</td>
# </tr>
# <tr>
# <td>Julian Vanecek</td>
# <td>TBD</td>
# <td>Online</td>
# </tr>
# </tbody>
# </table>

# %%
soup.find('a')
# Out:
# <a href="#description">Description</a>
